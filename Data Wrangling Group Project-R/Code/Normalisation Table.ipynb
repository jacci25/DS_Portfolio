# %% [markdown]
# ## Normalising Crime and School count in each TA
# Normalize crime and school data to the population in each Territorial Authority (TA).
# Calculate the crime and school counts per 10,000 people.

# %%
# loading the necessary libraries
library(dplyr)
library(tidyverse)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.2.3"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'tidyverse' was built under R version 4.2.3"
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"
# Warning message:
# "package 'tibble' was built under R version 4.2.3"
# Warning message:
# "package 'purrr' was built under R version 4.2.3"
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ readr     2.1.4
# ✔ ggplot2   3.4.3     ✔ stringr   1.5.0
# ✔ lubridate 1.9.2     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.0
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# read four CSV files
data_crime <- read.csv("Data/Final_crime_by_TA.csv")
data_housing <- read.csv("Data/Final_housedata.csv")
data_population <- read.csv("Data/Final_Population_Data.csv")
data_school <- read.csv("Data/Final_School_Data.csv")

# exclude the first column
data_crime <- data_crime[,-1]

# %%
# Normalising crime data

# Step 1: Sum up total victimizations for each Territorial Authority
data_crime <- data_crime %>% 
    group_by(Territorial_Authority)  %>% 
    summarise(Total_Victimisations = sum(Total_Victimisations))

# Step 2: Join the crime data with population data based on Territorial Authority
data_crime_norming <- left_join(data_crime,data_population,by = 'Territorial_Authority')

# Step 3: Calculate victimizations per 10,000 people
data_crime_norming$Victimisations_Per_10000 <- round((data_crime_norming$Total_Victimisations / data_crime_norming$Total_Population) * 10000)

# Step 4: Remove unnecessary columns (Total_Victimisations and Total_Population)
data_crime_norming <- data_crime_norming %>%
  select(-Total_Victimisations, -Total_Population)

# Step 5: Print the resulting normalized crime data
data_crime_norming
# Out:
#    Territorial_Authority              Victimisations_Per_10000
# 1  Area Outside Territorial Authority  NA
# 2  Ashburton District                 169
# 3  Auckland                           391
# 4  Buller District                    252
# 5  Carterton District                 155
# 6  Central Hawke's Bay District       158
# 7  Central Otago District             103
# 8  Chatham Islands Territory           88
# 9  Christchurch City                  549
# 10 Clutha District                    154
# 11 Dunedin City                       229
# 12 Far North District                 391
# 13 Gisborne District                  421
# 14 Gore District                      215
# 15 Grey District                      264
# 16 Hamilton City                      644
# 17 Hastings District                  399
# 18 Hauraki District                   340
# 19 Horowhenua District                400
# 20 Hurunui District                   137
# 21 Invercargill City                  375
# 22 Kaikoura District                  310
# 23 Kaipara District                   217
# 24 Kapiti Coast District              252
# 25 Kawerau District                   419
# 26 Lower Hutt City                    485
# 27 Mackenzie District                 117
# 28 Manawatu District                  268
# 29 Marlborough District               232
# 30 Masterton District                 396
# ⋮  ⋮                                  ⋮
# 39 Queenstown-Lakes District          175
# 40 Rangitikei District                220
# 41 Rotorua District                   629
# 42 Ruapehu District                   321
# 43 Selwyn District                    132
# 44 South Taranaki District            333
# 45 South Waikato District             402
# 46 South Wairarapa District           197
# 47 Southland District                 132
# 48 Stratford District                 233
# 49 Tararua District                   277
# 50 Tasman District                    182
# 51 Taupo District                     401
# 52 Tauranga City                      404
# 53 Thames-Coromandel District         276
# 54 Timaru District                    197
# 55 Upper Hutt City                    342
# 56 Waikato District                   274
# 57 Waimakariri District               206
# 58 Waimate District                   159
# 59 Waipa District                     279
# 60 Wairoa District                    350
# 61 Waitaki District                   133
# 62 Waitomo District                   305
# 63 Wellington City                    318
# 64 Western Bay of Plenty District     212
# 65 Westland District                  153
# 66 Whakatane District                 409
# 67 Whanganui District                 427
# 68 Whangarei District                 391

# %%
# Normalising school data

# Step 1: Sum up total school counts for each Territorial Authority
data_school <- data_school  %>% 
    group_by(Territorial_Authority)  %>% 
    summarise(School_Count = sum(School_Count))

# Step 2: Join the school data with population data based on Territorial Authority
data_school_norming <- left_join(data_school,data_population,by = 'Territorial_Authority')

# Step 3: Calculate schools per 10,000 people
data_school_norming$School_Per_10000 <- round((data_school_norming$School_Count / data_school_norming$Total_Population) * 10000)

# Step 4: Remove unnecessary columns (School_Count and Total_Population)
data_school_norming <- data_school_norming %>%
        select(-School_Count, -Total_Population)

# Step 5: Print the resulting normalized school data
data_school_norming
# Out:
#    Territorial_Authority          School_Per_10000
# 1  Ashburton District              6
# 2  Auckland                        3
# 3  Buller District                 9
# 4  Carterton District              6
# 5  Central Hawke's Bay District   11
# 6  Central Otago District          6
# 7  Chatham Islands Territory      38
# 8  Christchurch City               4
# 9  Clutha District                13
# 10 Dunedin City                    6
# 11 Far North District             10
# 12 Gisborne District              10
# 13 Gore District                   9
# 14 Grey District                  10
# 15 Hamilton City                   3
# 16 Hastings District               7
# 17 Hauraki District               10
# 18 Horowhenua District             6
# 19 Hurunui District                9
# 20 Invercargill City               5
# 21 Kaikoura District              12
# 22 Kaipara District                8
# 23 Kapiti Coast District           3
# 24 Kawerau District                6
# 25 Lower Hutt City                 5
# 26 Mackenzie District             15
# 27 Manawatu District               8
# 28 Marlborough District            6
# 29 Masterton District              7
# 30 Matamata-Piako District         8
# ⋮  ⋮                              ⋮
# 38 Queenstown-Lakes District       3
# 39 Rangitikei District            14
# 40 Rotorua District                6
# 41 Ruapehu District               17
# 42 Selwyn District                 4
# 43 South Taranaki District        10
# 44 South Waikato District          8
# 45 South Wairarapa District        7
# 46 Southland District             12
# 47 Stratford District             13
# 48 Tararua District               10
# 49 Tasman District                 6
# 50 Taupo District                  5
# 51 Tauranga City                   3
# 52 Thames-Coromandel District      7
# 53 Timaru District                 6
# 54 Upper Hutt City                 4
# 55 Waikato District                7
# 56 Waimakariri District            4
# 57 Waimate District               11
# 58 Waipa District                  6
# 59 Wairoa District                15
# 60 Waitaki District                9
# 61 Waitomo District               18
# 62 Wellington City                 4
# 63 Western Bay of Plenty District  4
# 64 Westland District              14
# 65 Whakatane District              9
# 66 Whanganui District              8
# 67 Whangarei District              5

# %%
# join the normalized crime data, housing data, and school data 

# Step 1: Left join the normalized crime data with housing data using 'Territorial_Authority' as the common column
norming_data <- left_join(data_crime_norming,data_housing, by= 'Territorial_Authority')

# Step 2: Left join the result from step 1 with the normalized school data using 'Territorial_Authority' as the common column
final_norming_data <- left_join(norming_data, data_school_norming, by='Territorial_Authority')

# Step 3: Print the final joined dataset
final_norming_data
# Out:
#    Territorial_Authority              Victimisations_Per_10000 Price
# 1  Area Outside Territorial Authority  NA                           NA
# 2  Ashburton District                 169                       532157
# 3  Auckland                           391                      1259185
# 4  Buller District                    252                       336345
# 5  Carterton District                 155                       633301
# 6  Central Hawke's Bay District       158                       588040
# 7  Central Otago District             103                       788144
# 8  Chatham Islands Territory           88                           NA
# 9  Christchurch City                  549                       730646
# 10 Clutha District                    154                       392835
# 11 Dunedin City                       229                       616117
# 12 Far North District                 391                       700402
# 13 Gisborne District                  421                       589585
# 14 Gore District                      215                       395015
# 15 Grey District                      264                       361677
# 16 Hamilton City                      644                       800437
# 17 Hastings District                  399                       765170
# 18 Hauraki District                   340                       631049
# 19 Horowhenua District                400                       551960
# 20 Hurunui District                   137                       624404
# 21 Invercargill City                  375                       456153
# 22 Kaikoura District                  310                       566219
# 23 Kaipara District                   217                       818262
# 24 Kapiti Coast District              252                       805926
# 25 Kawerau District                   419                       389679
# 26 Lower Hutt City                    485                       768115
# 27 Mackenzie District                 117                       750518
# 28 Manawatu District                  268                       612575
# 29 Marlborough District               232                       682993
# 30 Masterton District                 396                       557633
# ⋮  ⋮                                  ⋮                        ⋮
# 39 Queenstown-Lakes District          175                      1670801
# 40 Rangitikei District                220                       431086
# 41 Rotorua District                   629                       638234
# 42 Ruapehu District                   321                       369189
# 43 Selwyn District                    132                       801054
# 44 South Taranaki District            333                       437608
# 45 South Waikato District             402                       426624
# 46 South Wairarapa District           197                       766986
# 47 Southland District                 132                       492354
# 48 Stratford District                 233                       471430
# 49 Tararua District                   277                       400978
# 50 Tasman District                    182                       769331
# 51 Taupo District                     401                       829769
# 52 Tauranga City                      404                      1017984
# 53 Thames-Coromandel District         276                      1157623
# 54 Timaru District                    197                       500787
# 55 Upper Hutt City                    342                       725534
# 56 Waikato District                   274                       726521
# 57 Waimakariri District               206                       697534
# 58 Waimate District                   159                       442382
# 59 Waipa District                     279                       871229
# 60 Wairoa District                    350                       417440
# 61 Waitaki District                   133                       467713
# 62 Waitomo District                   305                       398629
# 63 Wellington City                    318                      1019077
# 64 Western Bay of Plenty District     212                       976065
# 65 Westland District                  153                       394958
# 66 Whakatane District                 409                       728386
# 67 Whanganui District                 427                       499207
# 68 Whangarei District                 391                       736658
#    School_Per_10000
# 1  NA
# 2   6
# 3   3
# 4   9
# 5   6
# 6  11
# 7   6
# 8  38
# 9   4
# 10 13
# 11  6
# 12 10
# 13 10
# 14  9
# 15 10
# 16  3
# 17  7
# 18 10
# 19  6
# 20  9
# 21  5
# 22 12
# 23  8
# 24  3
# 25  6
# 26  5
# 27 15
# 28  8
# 29  6
# 30  7
# ⋮  ⋮
# 39  3
# 40 14
# 41  6
# 42 17
# 43  4
# 44 10
# 45  8
# 46  7
# 47 12
# 48 13
# 49 10
# 50  6
# 51  5
# 52  3
# 53  7
# 54  6
# 55  4
# 56  7
# 57  4
# 58 11
# 59  6
# 60 15
# 61  9
# 62 18
# 63  4
# 64  4
# 65 14
# 66  9
# 67  8
# 68  5

# %%
# write to a CSV file
final_norming_data %>% 
    write.csv("Data/Final_norming_data.csv")

# %% [markdown]
# End of Notebook
